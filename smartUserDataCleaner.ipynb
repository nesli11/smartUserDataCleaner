# %%
raw_data ="  AhMeT  yILMAZ ;  23 ;  1.78 ;  ahmetYILMAZ@GMAIL.Com   "

# %%
info = raw_data.strip().split(";")

# %%
info
# Out:
# ['AhMeT  yILMAZ ', '  23 ', '  1.78 ', '  ahmetYILMAZ@GMAIL.Com']

# %% [markdown]
# İSİM-SOYİSİM

# %%
name_surname = info[0].split()

# %%
name = name_surname[0].strip().lower().title()

# %%
surname = name_surname[1].strip().lower().title()

# %%
fullname = name + " " + surname

# %% [markdown]
# YAŞ

# %%
ageplus = float(info[1].strip())+10

# %% [markdown]
# BOY

# %%
height = float(info[2].strip())*100

# %% [markdown]
# MAİL

# %%
email = info[3].strip().lower()

# %%
email.find("@")
# Out:
# 11

# %%
email = email[:3]

# %% [markdown]
# ÇIKTI

# %%
print(f"Kullanıcı: {fullname}\nYaş (10 yıl sonra): {ageplus}\nBoy (cm): {height}\nEmail kullanıcı kodu: {email}")
# Out:
# Kullanıcı: Ahmet Yilmaz
# Yaş (10 yıl sonra): 33.0
# Boy (cm): 178.0
# Email kullanıcı kodu: ahm
